# %% [markdown]
# # HW1
# 我選擇的是一筆關於 Apple Store Apps 的相關資訊
# #### 1. 你選的這組資料為何重要
# 現在社會，智慧型手機已是人手一機，電視廣告 87% 都在廣告手機遊戲，可想而知手機 App 這塊市場是百家爭鳴之地，誰能掌握使用者的喜好便能掌握商機。因此透過此筆資料的分析，或許我們可以瞭解人們點擊 App 的一些習性(有些 App 很好用，只是缺乏包裝)或是哪些類型的遊戲較吸引人。
# #### 2. 資料從何而來
# 這筆資料的蒐集方式是透過 jQuery 的方式抓取所有在 Google play 上面的開放資訊。(如果我英文理解沒錯的話...)
#
# #### 3. 蒐集而來的資料型態為何
# 這筆資料主要包含 5 個連續型變數 (評價、回覆次數、安裝次數、檔案大小、價格)、3 個離散型變數 (App 類型、目前版本、Android 版本)以及 App 名稱與最後更新日期
#
# #### 4. 這組資料想解決的問題如何評估
# 我認為此筆資料雖然變數不多，但仍有機會做一些分群的分析，透過討論度(回覆次數)、類型、價格來反應:安裝次數或是評價，或許可以建議開發 App 相關的企業看看要往哪個方向前進。
# Ex: 今天我的目標就是要下載次數高，評價方面及格就好(炒短線拉)，那我可能會從這筆資料summary發現免費 & 交友相關的 app 最可以達成我的目的，那可能會比較考慮往這塊著手。
# # HW2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請思考如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績代表更多消費者願意選擇我提供的載客服務，也就代表"搭乘次數"提升
# 假設隨著"價錢降低" & "等待時間"降低會提升乘車意願 s.t. "搭乘次數"提升
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 等待時間可定義為: 透過車隊收到叫車通知到確實搭載到客人 (自行蒐集)
# 價錢可透過每次搭載服務的營收計算 (自行蒐集)
# #### 3. 蒐集而來的資料型態為何
# 搭乘次數: numeric data
# 等待時間: numeric data (單位換算成分鐘)
# 價錢: numeric data (標準化後單位為台幣/公里)
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 透過確實降低價錢以及增加車輛密集度以達到降低等待時間，驗證在這兩個數值皆降低的情況，實際乘車人次與預估乘車人次相差多少
# # HW3
# #### 寫個函式計算 Mean Square Error (同時比較與 Mean Absolute Error 的差異)
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = sum((y-y_hat)**2)/len(y)
    return(mse)

def mean_absolute_error(y, y_hat):
    mae = sum(abs(y-y_hat))/len(y)
    return(mae)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 286.357
# The Mean absolute error is 13.296
